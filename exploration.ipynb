# %% [markdown]
# This is the file for exploration

# %%
# imports

import numpy as np
import matplotlib as plt
import pandas as pd
import csv

# %%
#import data
train_data = []
columns = []
with open('train.csv', newline='') as csvfile:
    train_data_reader = csv.reader(csvfile)
    first = True
    for line in train_data_reader:
        if first:
            columns.append(line)
            first = False
        else:
            train_data.append(line)
train_data = pd.DataFrame(train_data, columns=columns)

# %%
test_data = []
with open('test.csv', newline='') as csvfile:
    test_data_reader = csv.reader(csvfile)
    for line in test_data_reader:
        test_data.append(line)
test_data = pd.DataFrame(test_data)

# %%
train_data.head()
# Out:
#   Id MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape  \
# 0  1         60       RL          65    8450   Pave    NA      Reg
# 1  2         20       RL          80    9600   Pave    NA      Reg
# 2  3         60       RL          68   11250   Pave    NA      IR1
# 3  4         70       RL          60    9550   Pave    NA      IR1
# 4  5         60       RL          84   14260   Pave    NA      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0     NA    NA          NA       0      2
# 1         Lvl    AllPub  ...        0     NA    NA          NA       0      5
# 2         Lvl    AllPub  ...        0     NA    NA          NA       0      9
# 3         Lvl    AllPub  ...        0     NA    NA          NA       0      2
# 4         Lvl    AllPub  ...        0     NA    NA          NA       0     12
#
#   YrSold SaleType SaleCondition SalePrice
# 0   2008       WD        Normal    208500
# 1   2007       WD        Normal    181500
# 2   2008       WD        Normal    223500
# 3   2006       WD       Abnorml    140000
# 4   2008       WD        Normal    250000
#
# [5 rows x 81 columns]

# %%
num_data_train = []
for col in train_data.columns:
    try:
        train_data[col] = train_data[col].replace(',', '').astype(float)
    except:
        pass
    if train_data[col].dtype in ['float64', 'int64']:
        num_data_train.append(col)

print(num_data_train)
correlation_matrix = train_data[num_data_train].corr()
corr_saleprice = correlation_matrix['SalePrice']
print()
# Out:
# [('Id',), ('MSSubClass',), ('LotArea',), ('OverallQual',), ('OverallCond',), ('YearBuilt',), ('YearRemodAdd',), ('BsmtFinSF1',), ('BsmtFinSF2',), ('BsmtUnfSF',), ('TotalBsmtSF',), ('1stFlrSF',), ('2ndFlrSF',), ('LowQualFinSF',), ('GrLivArea',), ('BsmtFullBath',), ('BsmtHalfBath',), ('FullBath',), ('HalfBath',), ('BedroomAbvGr',), ('KitchenAbvGr',), ('TotRmsAbvGrd',), ('Fireplaces',), ('GarageCars',), ('GarageArea',), ('WoodDeckSF',), ('OpenPorchSF',), ('EnclosedPorch',), ('3SsnPorch',), ('ScreenPorch',), ('PoolArea',), ('MiscVal',), ('MoSold',), ('YrSold',), ('SalePrice',)]

# %%
#print(corr_saleprice)
#print(corr_saleprice['SalePrice'][:])
ordered_sale_coor = corr_saleprice.sort_values('SalePrice')
#print(ordered_sale_coor)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_92222/3780136268.py in ?()
#       1 #print(corr_saleprice)
#       2 #print(corr_saleprice['SalePrice'][:])
# ----> 3 ordered_sale_coor = corr_saleprice.sort_values('SalePrice')
#       4 #print(ordered_sale_coor)
#
# ~/CSGames/pratique_25/environment/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# ~/CSGames/pratique_25/environment/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1921             else:
#    1922                 multi_message = ""
#    1923
#    1924             label_axis_name = "column" if axis == 0 else "index"
# -> 1925             raise ValueError(
#    1926                 f"The {label_axis_name} label '{key}' is not unique.{multi_message}"
#    1927             )
#    1928
#
# ValueError: The column label 'SalePrice' is not unique.
# For a multi-index, the label must be a tuple with elements corresponding to each level.

# %%
[]
